# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading in the CSV and dropping the NaN values ###

# %%
###Read in data csv file and choose which columns we want to be included###
evict = pd.read_csv("data/Eviction_Notices.csv", engine='python', on_bad_lines='skip')
    
bad_reasons = evict[['Eviction ID', 'File Date', 'Non Payment', 'Nuisance', 'Illegal Use', 'Unapproved Subtenant', 'Demolition', 'Ellis Act WithDrawal', 'Late Payments', 'Failure to Sign Renewal']].dropna()
bad_reasons
# Out:
#        Eviction ID   File Date  Non Payment  Nuisance  Illegal Use  \
# 0          M222138  12/12/2022        False      True        False
# 1          M211838  12/06/2021        False      True        False
# 2          M222033  11/14/2022        False     False        False
# 3          M221840  10/18/2022        False     False        False
# 4          M120930  06/21/2012        False     False        False
# ...            ...         ...          ...       ...          ...
# 158041     M020356  03/25/2002        False     False        False
# 158042     M101330  09/24/2010        False     False        False
# 158043     M070731  04/25/2007        False     False        False
# 158044     M061330  08/09/2006        False     False        False
# 158045     M021493  10/08/2002        False     False        False
#
#         Unapproved Subtenant  Demolition  Ellis Act WithDrawal  Late Payments  \
# 0                      False       False                 False          False
# 1                      False       False                 False          False
# 2                      False       False                 False          False
# 3                      False       False                 False          False
# 4                      False       False                 False          False
# ...                      ...         ...                   ...            ...
# 158041                 False       False                 False          False
# 158042                 False       False                 False          False
# 158043                 False       False                  True          False
# 158044                 False       False                 False          False
# 158045                 False       False                  True          False
#
#         Failure to Sign Renewal
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 158041                    False
# 158042                    False
# 158043                    False
# 158044                    False
# 158045                    False
#
# [158046 rows x 10 columns]

# %%
for col in evict.columns:
    print(col)
# Out:
# Eviction ID
# Address
# City
# State
# Eviction Notice Source Zipcode
# File Date
# Non Payment
# Breach
# Nuisance
# Illegal Use
# Failure to Sign Renewal
# Access Denial
# Unapproved Subtenant
# Owner Move In
# Demolition
# Capital Improvement
# Substantial Rehab
# Ellis Act WithDrawal
# Condo Conversion
# Roommate Same Unit
# Other Cause
# Late Payments
# Lead Remediation
# Development
# Good Samaritan Ends
# Constraints Date
# Supervisor District
# Neighborhoods - Analysis Boundaries
# Location
# Shape
# SF Find Neighborhoods
# Current Police Districts
# Current Supervisor Districts
# Analysis Neighborhoods
# DELETE - Neighborhoods
# DELETE - Police Districts
# DELETE - Supervisor Districts
# DELETE - Fire Prevention Districts
# DELETE - Zip Codes
# CBD, BID and GBD Boundaries as of 2017
# Central Market/Tenderloin Boundary
# Areas of Vulnerability, 2016
# Central Market/Tenderloin Boundary Polygon - Updated
# Fix It Zones as of 2018-02-07
# Neighborhoods

# %%
###same as last cell, just include which neighborhoods they were in. however, some neighborhoods were NaN so we dropped those values and got a different graph###

bad_reasons_with_neighborhood = evict[['Eviction ID', 'Address','File Date', 'Non Payment', 'Nuisance', 'Illegal Use', 'Unapproved Subtenant', 'Demolition', 'Ellis Act WithDrawal', 'Late Payments', 'Failure to Sign Renewal', 'Neighborhoods - Analysis Boundaries']]

sampled = bad_reasons_with_neighborhood.sample(5000).rename({'Neighborhoods - Analysis Boundaries': 'Neighborhoods'}, axis=1)
sampled.head(20)
# Out:
#        Eviction ID                            Address   File Date  \
# 97807      M220999       1300 Block Of Jessie  Street  07/01/2022
# 58859      M181739       200 Block Of Miramar  Avenue  06/04/2018
# 25967      M071079       400 Block Of Vallejo  Street  07/09/2007
# 48063      M200125          600 Block Of Polk  Street  01/21/2020
# 131349     E981992      1000 Block Of Pacific  Avenue  08/31/1998
# 47961      M150578       1400 Block Of Revere  Avenue  03/23/2015
# 108198     M020041  100 Block Of Mount Vernon  Avenue  01/11/2002
# 60326      M221824          400 Block Of Eddy  Street  10/12/2022
# 79183      M050709     200 Block Of Ellsworth  Street  05/23/2005
# 53325      M141340        600 Block Of Moscow  Street  07/24/2014
# 65197      M020631      0 Block Of Vandewater  Street  05/17/2002
# 35464      RE01908      100 Block Of Shotwell  Street  05/22/1997
# 80477      E981728      2700 Block Of Lombard  Street  07/31/1998
# 135224     M121487       1100 Block Of Market  Street  08/16/2012
# 73792      M011631        300 Block Of Baltimore  Way  09/10/2001
# 106129     M211266  1800 Block Of Leavenworth  Street  09/13/2021
# 100132     M151454      300 Block Of Bartlett  Street  06/10/2015
# 89891      M153289    200 Block Of San Carlos  Street  12/01/2015
# 38593      M2K0370      2400 Block Of Taraval  Street  03/08/2000
# 72548      M061790       3000 Block Of Ortega  Street  11/02/2006
#
#         Non Payment  Nuisance  Illegal Use  Unapproved Subtenant  Demolition  \
# 97807         False      True        False                 False       False
# 58859         False     False        False                 False       False
# 25967          True     False        False                 False       False
# 48063         False      True        False                 False       False
# 131349        False      True        False                 False       False
# 47961         False      True        False                 False       False
# 108198        False     False        False                 False       False
# 60326         False     False        False                 False       False
# 79183         False     False        False                 False       False
# 53325         False     False        False                 False       False
# 65197         False      True        False                 False       False
# 35464         False     False        False                 False       False
# 80477          True     False        False                 False       False
# 135224        False     False        False                 False       False
# 73792         False     False        False                 False       False
# 106129        False     False        False                  True       False
# 100132        False      True        False                 False       False
# 89891         False     False        False                 False       False
# 38593         False     False        False                 False       False
# 72548         False     False        False                 False       False
#
#         Ellis Act WithDrawal  Late Payments  Failure to Sign Renewal  \
# 97807                  False          False                    False
# 58859                   True          False                    False
# 25967                  False          False                    False
# 48063                  False          False                    False
# 131349                 False          False                    False
# 47961                  False          False                    False
# 108198                 False          False                    False
# 60326                  False          False                    False
# 79183                  False          False                    False
# 53325                  False          False                    False
# 65197                  False          False                    False
# 35464                   True          False                    False
# 80477                  False          False                    False
# 135224                 False          False                    False
# 73792                  False          False                    False
# 106129                 False          False                    False
# 100132                 False          False                    False
# 89891                  False           True                    False
# 38593                  False          False                    False
# 72548                  False          False                    False
#
#                      Neighborhoods
# 97807                      Mission
# 58859   Oceanview/Merced/Ingleside
# 25967                  North Beach
# 48063                   Tenderloin
# 131349                    Nob Hill
# 47961        Bayview Hunters Point
# 108198               Outer Mission
# 60326                   Tenderloin
# 79183               Bernal Heights
# 53325                    Excelsior
# 65197                  North Beach
# 35464                      Mission
# 80477                       Marina
# 135224             South of Market
# 73792                    Excelsior
# 106129                    Nob Hill
# 100132                     Mission
# 89891                      Mission
# 38593              Sunset/Parkside
# 72548              Sunset/Parkside

# %%
neighborhood_counts = sampled[['Neighborhoods']].value_counts().reset_index(name='counts')
neighborhood_counts.describe()
# Out:
#            counts
# count   40.000000
# mean   124.850000
# std    105.463458
# min      1.000000
# 25%     54.250000
# 50%    119.500000
# 75%    157.000000
# max    531.000000

# %%
###plot evictions per neighborhood###
neighborhood_counts.plot('Neighborhoods', 'counts')
# Out:
# <AxesSubplot: xlabel='Neighborhoods'>

# %%
neighs = list(neighborhood_counts["Neighborhoods"])
counts = list(neighborhood_counts["counts"])
fig, ax = plt.subplots()
plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.xlabel("Neighborhoods", labelpad = 10)
plt.bar(neighs, counts)
# Out:
# <BarContainer object of 40 artists>

# %%
nuisances = sampled[['Nuisance']]

# %%
reasons = sampled.iloc[:, 3:11]
reasons
# Out:
#         Non Payment  Nuisance  Illegal Use  Unapproved Subtenant  Demolition  \
# 95319          True     False        False                 False       False
# 10323         False      True        False                 False       False
# 103208        False     False        False                 False       False
# 38479         False     False        False                 False       False
# 93335         False     False        False                 False       False
# ...             ...       ...          ...                   ...         ...
# 38544         False     False        False                 False       False
# 22273         False     False        False                 False       False
# 154170        False     False        False                 False       False
# 30701         False     False        False                 False       False
# 19726         False     False        False                 False       False
#
#         Ellis Act WithDrawal  Late Payments  Failure to Sign Renewal
# 95319                  False          False                    False
# 10323                  False          False                    False
# 103208                 False          False                    False
# 38479                  False          False                    False
# 93335                  False          False                    False
# ...                      ...            ...                      ...
# 38544                  False          False                    False
# 22273                  False          False                    False
# 154170                 False          False                    False
# 30701                  False          False                    False
# 19726                  False          False                    False
#
# [5000 rows x 8 columns]

# %%
for col in reasons.columns:
    print(sampled[[col]].value_counts().reset_index(name='counts'))

###plot true and false for one column###
payment_ocurr = reasons[['Non Payment']].value_counts().reset_index(name='counts')
payment_ocurr

pay_bool = list(payment_ocurr['Non Payment'])
pay_counts = list(payment_ocurr['counts'])
plt.bar(pay_bool, pay_counts)

#create dataframe with true and false occurrences, maybe make this one of the tests#
columnNames = reasons.columns

for i in reasons.columns:
    true_occurrences = reasons[i].sum()
    false_occurrences = len(reasons) - true_occurrences

data = {"True": true_occurrences, "False": false_occurrences}
combined = pd.DataFrame(data, columnNames)
print(true_occurrences)
# Out:
#    Non Payment  counts
# 0        False    4673
# 1         True     327
#    Nuisance  counts
# 0     False    4023
# 1      True     977
#    Illegal Use  counts
# 0        False    4887
# 1         True     113
#    Unapproved Subtenant  counts
# 0                 False    4916
# 1                  True      84
#    Demolition  counts
# 0       False    4859
# 1        True     141
#    Ellis Act WithDrawal  counts
# 0                 False    4519
# 1                  True     481
#    Late Payments  counts
# 0          False    4816
# 1           True     184
#    Failure to Sign Renewal  counts
# 0                    False    4985
# 1                     True      15
# 15

# %%
###another method to find number of true and false occurrences per reason###
columnNames = reasons.columns

for col in columnNames:
    trues = reasons[col].sum()
    falses = len(reasons) - trues
    lst1 = [trues]
    lst2 = [falses]
    print(trues, falses)
# Out:
# 327 4673
# 977 4023
# 113 4887
# 84 4916
# 141 4859
# 481 4519
# 184 4816
# 15 4985
